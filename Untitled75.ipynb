# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv("student.csv")
x=dataset.iloc[: ,[0,2,4]].values
y=dataset.iloc[: , 5].values 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x[ : , 0]=le.fit_transform (x[ : , 0])
x[ : , 2]=le.fit_transform (x[ : , 2])
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
a=ColumnTransformer(transformers=[("encoder", OneHotEncoder(), [1])], remainder="passthrough")
x=np.array(a.fit_transform(x))
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2, random_state=0)
from sklearn.linear_model import LinearRegression
l=LinearRegression()
l.fit (x_train,y_train)
y_pred=l.predict(x_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 66.38  62.  ]
#  [ 67.    87.  ]
#  [ 68.88  40.  ]
#  [ 68.    77.  ]
#  [ 63.5   69.  ]
#  [ 68.38  78.  ]
#  [ 66.38  67.  ]
#  [ 67.    46.  ]
#  [ 73.88  99.  ]
#  [ 63.    46.  ]
#  [ 63.5   54.  ]
#  [ 62.5   53.  ]
#  [ 76.75  91.  ]
#  [ 67.    84.  ]
#  [ 69.38  48.  ]
#  [ 58.5   33.  ]
#  [ 63.    57.  ]
#  [ 71.75  81.  ]
#  [ 65.88  50.  ]
#  [ 76.75  80.  ]
#  [ 63.5   63.  ]
#  [ 62.5   52.  ]
#  [ 62.5   73.  ]
#  [ 70.88  66.  ]
#  [ 70.88  55.  ]
#  [ 67.    68.  ]
#  [ 67.    65.  ]
#  [ 68.88  60.  ]
#  [ 58.5   53.  ]
#  [ 69.38  69.  ]
#  [ 58.5   71.  ]
#  [ 73.88  93.  ]
#  [ 62.5   82.  ]
#  [ 58.5   48.  ]
#  [ 64.38  52.  ]
#  [ 67.    92.  ]
#  [ 65.88  92.  ]
#  [ 68.88  69.  ]
#  [ 68.38  57.  ]
#  [ 58.5   69.  ]
#  [ 68.    76.  ]
#  [ 63.    62.  ]
#  [ 63.    71.  ]
#  [ 68.38  57.  ]
#  [ 63.5   71.  ]
#  [ 68.38  52.  ]
#  [ 58.    77.  ]
#  [ 63.5   59.  ]
#  [ 71.75  77.  ]
#  [ 66.38  44.  ]
#  [ 67.    47.  ]
#  [ 67.    67.  ]
#  [ 58.    44.  ]
#  [ 63.    61.  ]
#  [ 76.75  39.  ]
#  [ 66.38  63.  ]
#  [ 62.5   47.  ]
#  [ 70.88  69.  ]
#  [ 68.38  81.  ]
#  [ 62.5   56.  ]
#  [ 70.88  68.  ]
#  [ 64.38  74.  ]
#  [ 69.38  42.  ]
#  [ 67.    69.  ]
#  [ 68.38  63.  ]
#  [ 68.38  59.  ]
#  [ 63.    76.  ]
#  [ 58.    47.  ]
#  [ 63.88  60.  ]
#  [ 73.88  61.  ]
#  [ 67.    81.  ]
#  [ 67.    90.  ]
#  [ 70.88  80.  ]
#  [ 64.38  58.  ]
#  [ 67.    64.  ]
#  [ 67.    71.  ]
#  [ 70.38  73.  ]
#  [ 63.    70.  ]
#  [ 58.5   29.  ]
#  [ 58.    73.  ]
#  [ 73.88  79.  ]
#  [ 66.38  79.  ]
#  [ 66.38  64.  ]
#  [ 68.38  79.  ]
#  [ 76.75  70.  ]
#  [ 62.5   77.  ]
#  [ 70.88  63.  ]
#  [ 68.38  94.  ]
#  [ 69.38  59.  ]
#  [ 66.38  43.  ]
#  [ 62.5   65.  ]
#  [ 58.5   54.  ]
#  [ 62.5   54.  ]
#  [ 70.88  73.  ]
#  [ 68.    86.  ]
#  [ 63.    70.  ]
#  [ 63.    63.  ]
#  [ 62.5   52.  ]
#  [ 70.88  61.  ]
#  [ 63.    70.  ]
#  [ 63.88  32.  ]
#  [ 67.    90.  ]
#  [ 62.5   67.  ]
#  [ 64.38  34.  ]
#  [ 67.    83.  ]
#  [ 64.38  67.  ]
#  [ 69.38  63.  ]
#  [ 65.88  52.  ]
#  [ 58.5   45.  ]
#  [ 68.88  87.  ]
#  [ 69.38  63.  ]
#  [ 68.38  73.  ]
#  [ 62.5   26.  ]
#  [ 70.38  54.  ]
#  [ 63.5   62.  ]
#  [ 63.5   67.  ]
#  [ 68.38  78.  ]
#  [ 70.38  79.  ]
#  [ 72.88  79.  ]
#  [ 63.88  54.  ]
#  [ 62.5   46.  ]
#  [ 58.    67.  ]
#  [ 69.38  88.  ]
#  [ 63.    82.  ]
#  [ 76.75  79.  ]
#  [ 63.88  40.  ]
#  [ 62.5   74.  ]
#  [ 69.38  70.  ]
#  [ 68.38  77.  ]
#  [ 63.5   61.  ]
#  [ 68.88  68.  ]
#  [ 68.    67.  ]
#  [ 63.    30.  ]
#  [ 70.38  81.  ]
#  [ 63.88  77.  ]
#  [ 66.38  61.  ]
#  [ 76.75  67.  ]
#  [ 68.88  64.  ]
#  [ 62.5   62.  ]
#  [ 68.    81.  ]
#  [ 76.75  68.  ]
#  [ 58.5   60.  ]
#  [ 68.    71.  ]
#  [ 63.    68.  ]
#  [ 58.    65.  ]
#  [ 68.    41.  ]
#  [ 58.    38.  ]
#  [ 63.    48.  ]
#  [ 63.88  71.  ]
#  [ 68.    97.  ]
#  [ 68.    58.  ]
#  [ 63.5   69.  ]
#  [ 64.38  88.  ]
#  [ 76.75  70.  ]
#  [ 69.38  64.  ]
#  [ 68.88  86.  ]
#  [ 67.    53.  ]
#  [ 63.5   52.  ]
#  [ 62.5   53.  ]
#  [ 63.    59.  ]
#  [ 58.    81.  ]
#  [ 62.5   40.  ]
#  [ 63.    53.  ]
#  [ 67.    97.  ]
#  [ 64.38  65.  ]
#  [ 58.    71.  ]
#  [ 64.38  67.  ]
#  [ 63.    81.  ]
#  [ 68.    66.  ]
#  [ 68.    68.  ]
#  [ 62.5   54.  ]
#  [ 68.38  57.  ]
#  [ 63.5   22.  ]
#  [ 68.38  56.  ]
#  [ 63.5   83.  ]
#  [ 68.    68.  ]
#  [ 68.88  73.  ]
#  [ 58.5   50.  ]
#  [ 68.38  93.  ]
#  [ 68.    88.  ]
#  [ 68.88  76.  ]
#  [ 63.5   77.  ]
#  [ 68.88  72.  ]
#  [ 63.    71.  ]
#  [ 69.38  67.  ]
#  [ 63.    72.  ]
#  [ 68.38  96.  ]
#  [ 66.38 100.  ]
#  [ 66.38  62.  ]
#  [ 68.    59.  ]
#  [ 68.    58.  ]
#  [ 70.88  64.  ]
#  [ 73.88  50.  ]
#  [ 62.5   71.  ]
#  [ 68.    58.  ]
#  [ 68.    63.  ]
#  [ 63.88  74.  ]
#  [ 68.38  84.  ]
#  [ 68.38  65.  ]
#  [ 68.38  62.  ]]
